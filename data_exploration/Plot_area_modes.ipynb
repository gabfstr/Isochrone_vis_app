# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"

cycle = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/Cycling.csv", delimiter=',')
drive = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/Driving.csv", delimiter=',')
transit = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/Transit.csv", delimiter=',')
walk = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/Walking.csv", delimiter=',')

day = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/transit_day_evolution.csv", delimiter=';')


morning6 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/morning6_drive.csv", delimiter=',')
morning7 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/morning7_drive.csv", delimiter=',')
morning8 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/morning8_drive.csv", delimiter=',')
morning9 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/morning9_drive.csv", delimiter=',')

afternoon15 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/afternoon15_drive.csv", delimiter=',')
afternoon16 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/afternoon16_drive.csv", delimiter=',')
afternoon17 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/afternoon17_drive.csv", delimiter=',')
afternoon18 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/afternoon18_drive.csv", delimiter=',')
afternoon19 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/afternoon19_drive.csv", delimiter=',')
afternoon20 = np.genfromtxt("/Users/gabrielfiastre/Isochrone_R_app/Isochrone_app/outputs/afternoon20_drive.csv", delimiter=',')

# %%
time = range(5,61)
figure, ax = plt.subplots()

line1, = plt.plot(time, cycle[1:], 'r', linewidth=2)
line2, = plt.plot(time, walk[1:], 'b', linewidth=2)
line3, = plt.plot(time, drive[1:], 'orange', linewidth=2)
line4, = plt.plot(time, transit[1:], 'k', linewidth=2)
plt.yticks(range(0,801, 200))
plt.title('Area of Isochrones from Les Halles', fontsize=24)
plt.xlabel(r'Time range (min)', fontsize=20)
plt.ylabel(r'Area ($km^{2}$)', fontsize=20)
plt.axis([5, 62, 0, 1000])
ax.annotate("Transit", (41,700), fontsize=12)
ax.annotate("Cycling", (43,350), fontsize=12, color='r')
ax.annotate("Driving", (52,200), fontsize=12, color='orange')
ax.annotate("Walking", (52,70), fontsize=12, color='b')

plt.show()

# %%
time = range(0,24)
plt.plot(time,day[1:], 'r', linewidth=2)
plt.title('Area of 20 min Isochrones from Les Halles with public transport', fontsize=16)
plt.xlabel(r'Hour of the day', fontsize=20)
plt.xticks(range(1,24,3))
plt.ylabel(r'Area ($km^{2}$)', fontsize=20)
plt.show()

# %%
time = range(5,61)
figure, ax = plt.subplots()



#line1, = plt.plot(time, morning6[1:], 'r', linewidth=2)
line1, = plt.plot(time, morning7[1:], 'b', linewidth=2)
line2, = plt.plot(time, morning8[1:], 'g', linewidth=2)
line3, = plt.plot(time, morning9[1:], 'r', linewidth=2)


plt.yticks(range(0,801, 200))
plt.title('Area of Isochrones from Les Halles', fontsize=24)
plt.xlabel(r'Time (min)', fontsize=20)
plt.ylabel(r'Area ($km^{2}$)', fontsize=20)
plt.axis([5, 62, 0, 1000])
#ax.annotate("6AM", (41,700), fontsize=12)
ax.annotate("7AM", (55,235), fontsize=12, color='b')
ax.annotate("8AM", (52.5,380), fontsize=12, color='g')
ax.annotate("9AM", (46,450), fontsize=12, color='r')

plt.show()

# %%
time = range(5,61)
figure, ax = plt.subplots()



#line1, = plt.plot(time, morning6[1:], 'r', linewidth=2)
line2, = plt.plot(time, afternoon17[1:], 'b', linewidth=2)
line3, = plt.plot(time, afternoon18[1:], 'g', linewidth=2)
line4, = plt.plot(time, afternoon19[1:], 'r', linewidth=2)
plt.yticks(range(0,801, 200))
plt.title('Area of Isochrones driving from Les Halles', fontsize=24)
plt.xlabel(r'Time (min)', fontsize=20)
plt.ylabel(r'Area ($km^{2}$)', fontsize=20)
plt.axis([5, 62, 0, 1000])
#ax.annotate("6AM", (41,700), fontsize=12)
ax.annotate("5PM", (55,235), fontsize=12, color='b')
ax.annotate("6PM", (52.5,380), fontsize=12, color='g')
ax.annotate("7PM", (46,450), fontsize=12, color='r')

plt.show()

# %%
line4, = plt.plot(time, afternoon17[1:], 'b', linewidth=2)
line5, = plt.plot(time, afternoon18[1:], 'g', linewidth=2)
line6, = plt.plot(time, afternoon19[1:], 'r', linewidth=2)

# %%
time = range(5,61)
figure, ax = plt.subplots()



#line1, = plt.plot(time, morning6[1:], 'r', linewidth=2)
line1, = plt.plot(time, morning7[1:], 'k', linewidth=2)
line2, = plt.plot(time, morning8[1:], 'lightgreen', linewidth=2)
line3, = plt.plot(time, morning9[1:], 'r', linewidth=2)

line4, = plt.plot(time, afternoon17[1:], 'darkblue', linewidth=2)
line5, = plt.plot(time, afternoon18[1:], 'darkgreen', linewidth=2)
line6, = plt.plot(time, afternoon19[1:], 'darkred', linewidth=2)


plt.yticks(range(0,801, 200))
plt.title('Area of Isochrones Driving from Les Halles', fontsize=24)
plt.xlabel(r'Time (min)', fontsize=20)
plt.ylabel(r'Area ($km^{2}$)', fontsize=20)
plt.axis([5, 62, 0, 1000])
#ax.annotate("6AM", (41,700), fontsize=12)
ax.annotate("7AM", (55,235), fontsize=12, color='k')
ax.annotate("8AM", (54,440), fontsize=12, color='lightgreen')
ax.annotate("9AM", (40,470), fontsize=12, color='r')
ax.annotate("5PM", (53,170), fontsize=12, color='darkblue')
ax.annotate("6PM", (52.5,380), fontsize=12, color='darkgreen')
ax.annotate("7PM", (46,450), fontsize=12, color='darkred')

plt.show()
